# %% [markdown]
# # Easy strategy lab (Jupyter)
#
# Use this notebook to prototype indicators and regime logic without Streamlit. The same helpers power **Easy mode → Auto backtest**.
#
# 1. Set `SYMBOL` and `LOOKBACK_DAYS`.
# 2. Run cells to load OHLCV and build the default indicator stack.
# 3. Optionally call `train_multi_window_regimes` or `run_rsi_threshold_heatmap` from `backtest_extras`.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve().parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

SYMBOL = "SPY"
LOOKBACK_DAYS = 365

# %%
from app_streamlit.easy_mode.data import load_ohlcv
from app_streamlit.easy_mode.backtest_core import build_auto_indicators_and_weights, default_params_from_spec
from app_streamlit.easy_mode.backtest_extras import train_multi_window_regimes

ohlcv = load_ohlcv(SYMBOL, LOOKBACK_DAYS)
spec = default_params_from_spec()
indicators, weights = build_auto_indicators_and_weights(ohlcv, spec)
ohlcv.head()

# %%
multi = train_multi_window_regimes(ohlcv, indicators, weights, spec)
{k: v["label"] for k, v in multi.items()}
