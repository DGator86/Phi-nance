# %% [markdown]
# # 03 – Custom Analysis Template
#
# Use this notebook as a starting point for bespoke analysis.

# %% [markdown]
# ## Setup
# 1. Configure your MLflow tracking URI.
# 2. Import `phinance.experiment.results` and `phinance.experiment.visualization`.
# 3. Pick a run/sweep scope.

# %%
# TODO: imports
# from phinance.experiment.results import list_runs
# from phinance.experiment.visualization import plot_learning_curve

# %% [markdown]
# ## Data loading

# %%
# TODO: select experiments and load runs into a DataFrame

# %% [markdown]
# ## Visualization

# %%
# TODO: create custom line/bar/parallel-coordinate figures

# %% [markdown]
# ## Insights and decisions

# %%
# TODO: document findings, best hyperparameters, and next experiments
