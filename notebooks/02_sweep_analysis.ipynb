# %% [markdown]
# # 02 – Sweep Analysis
#
# Compare child trials from a sweep and identify top performers.

# %%
from phinance.experiment.visualization import (
    parallel_coordinates,
    parameter_importance,
    plot_trial_comparison,
)

# %% [markdown]
# ## 1) Set sweep context
# Use a parent run id or sweep id used in tags.

# %%
sweep_id = 'YOUR_SWEEP_RUN_ID'
metric_name = 'val_reward'

# %% [markdown]
# ## 2) Trial comparison bar chart

# %%
bar_fig = plot_trial_comparison(sweep_id, metric=metric_name, top_k=20)
bar_fig

# %% [markdown]
# ## 3) Parallel coordinates view

# %%
pc_fig = parallel_coordinates(sweep_id, metric=metric_name)
pc_fig

# %% [markdown]
# ## 4) Parameter importance

# %%
imp_fig = parameter_importance(sweep_id, metric=metric_name)
imp_fig

# %% [markdown]
# ## 5) Next steps
# - Filter trials by tag.
# - Compare multiple sweeps.
# - Export charts for reports.
